# %%
def rectangle():
    rectangle=((1,1),(1,2),(1,3),(1,4),(1,5),
            (2,1),(2,5),(3,1),(3,5),
            (4,1),(4,2),(4,3),(4,4),(4,5))
    print("=====RECTANGLE=====")
    for i in range(1,6):
        for j in range(1,6):
            if(i,j) in rectangle:
                print("*",end=' ')
            else:
                print(' ',end=' ')
        print()
rectangle()
# Out:
# =====RECTANGLE=====
# * * * * *
# *       *
# *       *
# * * * * *
